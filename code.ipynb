# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiram-04/Diabetes-Disease-Classification/blob/main/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# <center> <h3> <span>Diabetes Disease Classification </span> </h3> </center>
## <span>⬇️ Import Libraries</span>
import pandas as pd
import numpy as np
import time
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
## <span>📚 Read the Dataset</span>
df = pd.read_csv('/content/diabetes.csv')
x = df.drop('Outcome',axis=1)
y = df['Outcome']
## <span>✂ Split the Data into Train and Test </span>
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=0)

x = X_train.values.T
y = y_train.values
### Hyperparameters
np.random.seed(420)
no_hidden_layers = 2
learning_rate = 0.01
no_epochs = 100
number_of_inputs = 8
output_neurons = 1

max_no_hidden_layers = 5
### Creating a dictionary with hyperparameters
def init_hyperparams_dict(max_no_hidden_layers):
    keys = ['no_hidden_layers']
    for i in range(max_no_hidden_layers):
        keys.append('no_neurons_hidden_layer_'+str(i))
        keys.append('activation_function_'+str(i))

    keys.extend(['output_activation_function', 'learning_rate', 'no_epochs'])
    hyperparams = dict.fromkeys(keys)
    return hyperparams


def add_params_dict(hyperparams, no_hidden_layers, max_no_hidden_layers, learning_rate, no_epochs):
    hyperparams['no_hidden_layers'] = no_hidden_layers
    i = 0

    while i < max_no_hidden_layers:
        if i < no_hidden_layers:
            hyperparams['no_neurons_hidden_layer_'+str(i)] = int(input('Enter number of neurons in Layer'+str(i+1)+': '))
            hyperparams['activation_function_'+str(i)] = str(input('Enter the Activation Function for Layer'+str(i+1)+': '))
        else:
            hyperparams["no_neurons_hidden_layer_"+str(i)] = None
            hyperparams["activation_function_"+str(i)] = None
        i += 1
    hyperparams['output_activation_function'] = str(input('Enter the Activation Function for output: '))
    hyperparams['learning_rate'] = learning_rate
    hyperparams['no_epochs'] = no_epochs
    return hyperparams
hyperparams = init_hyperparams_dict(max_no_hidden_layers)
hyperparams = add_params_dict(hyperparams, no_hidden_layers, max_no_hidden_layers, learning_rate, no_epochs)
hyperparams
weights = []
bias = []
def generate_wb(number_of_inputs, hyperparams):
    weights.append(np.random.uniform(low=-0.5, high=0.5, size=(number_of_inputs, hyperparams['no_neurons_hidden_layer_0'])))
    i = 0
    while i<hyperparams['no_hidden_layers']:
        if(i == hyperparams['no_hidden_layers'] - 1):

            weights.append(np.random.uniform(low=-0.5,high=0.5,size=(hyperparams['no_neurons_hidden_layer_'+str(i)], output_neurons)))
            bias.append(np.zeros((hyperparams['no_neurons_hidden_layer_'+str(i)], 1)))
        else:

            weights.append(np.random.uniform(low=-0.5,high=0.5,size=(hyperparams['no_neurons_hidden_layer_'+str(i)], hyperparams['no_neurons_hidden_layer_'+str(i+1)])))
            bias.append(np.zeros((hyperparams['no_neurons_hidden_layer_'+str(i)], 1)))
        i+=1
    bias.append(np.zeros((output_neurons, 1)))
    return weights, bias
### Acitvation Functions
def sigmoid(z):
    a=np.zeros([1,1])
    a=1/(1+np.exp(-z))
    return a

def sigmoid_derivative(A):
    return A*(1-A)

def ReLU(z):
    return np.maximum(z, 0)

def ReLU_derivative(z):
    return z > 0

def tanh(z):
    z=(np.exp(z)-np.exp(-z))/(np.exp(z)+np.exp(-z))
    z=1-z**2
    return z

def tanh_derivative(z):
    dz=1-z**2
    return dz
## <span> Forward Propagation</span>
def forward_propagation(weights, bias, hyperparams, x):
    z = []
    a = []
    i = 0
    while i <= hyperparams['no_hidden_layers']:
        if i == 0:
            z.append(np.matmul(weights[i].T,x) + bias[i])
        else:
            z.append(np.matmul(weights[i].T, a[i - 1]) + bias[i])
        if i == hyperparams['no_hidden_layers']:
            if(hyperparams['output_activation_function'] == 'sigmoid'):
                a.append(sigmoid(z[i]))
            elif(hyperparams['output_activation_function'] == 'tanh'):
                a.append(tanh(z[i]))
            elif(hyperparams['output_activation_function'] == 'relu'):
                a.append(ReLU(z[i]))
        else:
            if(hyperparams['activation_function_'+str(i)] == 'sigmoid'):
                a.append(sigmoid(z[i]))
            elif(hyperparams['activation_function_'+str(i)] == 'tanh'):
                a.append(tanh(z[i]))
            elif(hyperparams['activation_function_'+str(i)] == 'relu'):
                a.append(ReLU(z[i]))

        i+=1

    return z, a
### Log loss
def log_loss_calc(output, y):
    loss = 0
    loss =- 1 * np.sum(y * np.log(output + 1e-10) + ((1 - y) * np.log(1 - output + 1e-10)))
    loss = loss / y.shape[0]
    return loss
### Hinge Loss
def hinge_loss_calc(y, y_hat):
    y_new = np.array([-1 if i==0 else i for i in y])
    y_hat = np.array([-1 if i==0 else i for i in y_hat])
    hinge_loss = np.mean([max(0, 1-x*y) for x, y in zip(y_new, y_hat)])
    return hinge_loss

### Backward Propagation
dw = []
db = []
def generate_dwdb(hyperparams):
    dw.clear()
    db.clear()
    for i in range(hyperparams['no_hidden_layers']):
        dw.append(np.zeros_like(weights[i]))
        db.append(np.zeros_like(bias[i]))
    return dw, db
def backward_propagation(a, weights, bias, y, x):
    dz = []
    dz.append((a[no_hidden_layers]) - y)
    dw.append(np.matmul(a[no_hidden_layers - 1],dz[0].T)/y.shape[0])
    db.append(np.sum(dz[0],axis=0,keepdims=True)/y.shape[0])

    i = no_hidden_layers
    j = 1
    while i>0:

        if(hyperparams['activation_function_'+str(i-1)] == 'sigmoid'):
            dz.append(np.multiply(np.matmul(weights[i],dz[j-1]),sigmoid_derivative(a[i-1])))
        elif(hyperparams['activation_function_'+str(i-1)] == 'tanh'):
            dz.append(np.multiply(np.matmul(weights[i],dz[j-1]),tanh_derivative(a[i-1])))
        elif(hyperparams['activation_function_'+str(i-1)] == 'relu'):
            dz.append(np.multiply(np.matmul(weights[i],dz[j-1]),ReLU_derivative(a[i-1])))
        if(i!=1):
            dw.append(np.matmul(a[i-2], dz[j].T)/y.shape[0])
            db.append(np.sum(dz[j],axis=0, keepdims=True)/y.shape[0])
        elif(i==1):

            dw.append(np.matmul(x,dz[j].T)/y.shape[0])
            db.append(np.sum(dz[j], axis=0, keepdims=True)/y.shape[0])
        i-=1
        j+=1
    dz.reverse()
    db.reverse()
    dw.reverse()

    i=0
    while i<=no_hidden_layers:
        weights[i] = weights[i]-learning_rate*dw[i]
        bias[i] = bias[i]-learning_rate*db[i]
        i+=1

    return weights, bias, dw, db
def accuracy_calc(output):
    y_hat=[]
    correct=0
    accuracy=0
    for i, m in enumerate(output):
        if m<0.5:
            y_hat.append(0)
        elif m>=0.5:
            y_hat.append(1)

    correct=np.sum(y==y_hat)
    accuracy=correct/y.shape[0]
    return y_hat, correct, accuracy
t=time.time()
weights, bias = generate_wb(number_of_inputs, hyperparams)
for j in range(no_epochs):
    dw, db = generate_dwdb(hyperparams)
    z, a = forward_propagation(weights, bias, hyperparams, x)
    log_loss = log_loss_calc(a[no_hidden_layers][0], y)
    weights, bias, dw, db = backward_propagation(a, weights, bias, y, x)
    y_hat, correct, accuracy = accuracy_calc(a[no_hidden_layers][0])


    hinge_loss = hinge_loss_calc(y,y_hat)
    print('Total Correct Predictions: ',correct, '/', y.shape[0])
    print('Accuracy for the current Epoch {} = {:.2f}%'.format(j,accuracy*100))

print('*'*50, 'Training Complete', '*'*50)
print('time taken: ' ,time.time()-t)
print('Final LOG cost after training: {:.2f}'.format(log_loss))
print('Final HINGE loss after training : {:.2f}'.format(hinge_loss))
print('Final accuracy after training for {} epochs = {:.2f}%'.format((j + 1),(accuracy * 100)))
def predict_output(input_data, weights, bias, hyperparams):
    x = np.array(input_data).reshape(-1, 1)
    z, a = forward_propagation(weights, bias, hyperparams, x)
    predicted_output = np.max(a[hyperparams['no_hidden_layers']])
    return 1 if predicted_output >= 0.5 else 0

input_data = [1, 85, 66, 29, 0, 26.6, 0.351, 31]
prediction = predict_output(input_data, weights, bias, hyperparams)
print("Prediction:", prediction)
import joblib
joblib.dump((weights, bias,hyperparams), 'hyperparameters.joblib')
# Out:
# Enter number of neurons in Layer1: 5
# Enter the Activation Function for Layer1: sigmoid
# Enter number of neurons in Layer2: 10
# Enter the Activation Function for Layer2: relu
# Enter the Activation Function for output: sigmoid
# Total Correct Predictions:  242 / 537
# Accuracy for the current Epoch 0 = 45.07%
# Total Correct Predictions:  240 / 537
# Accuracy for the current Epoch 1 = 44.69%
# Total Correct Predictions:  244 / 537
# Accuracy for the current Epoch 2 = 45.44%
# Total Correct Predictions:  245 / 537
# Accuracy for the current Epoch 3 = 45.62%
# Total Correct Predictions:  244 / 537
# Accuracy for the current Epoch 4 = 45.44%
# Total Correct Predictions:  244 / 537
# Accuracy for the current Epoch 5 = 45.44%
# Total Correct Predictions:  243 / 537
# Accuracy for the current Epoch 6 = 45.25%
# Total Correct Predictions:  241 / 537
# Accuracy for the current Epoch 7 = 44.88%
# Total Correct Predictions:  239 / 537
# Accuracy for the current Epoch 8 = 44.51%
# Total Correct Predictions:  239 / 537
# Accuracy for the current Epoch 9 = 44.51%
# Total Correct Predictions:  239 / 537
# Accuracy for the current Epoch 10 = 44.51%
# Total Correct Predictions:  242 / 537
# Accuracy for the current Epoch 11 = 45.07%
# Total Correct Predictions:  248 / 537
# Accuracy for the current Epoch 12 = 46.18%
# Total Correct Predictions:  248 / 537
# Accuracy for the current Epoch 13 = 46.18%
# Total Correct Predictions:  249 / 537
# Accuracy for the current Epoch 14 = 46.37%
# Total Correct Predictions:  251 / 537
# Accuracy for the current Epoch 15 = 46.74%
# Total Correct Predictions:  257 / 537
# Accuracy for the current Epoch 16 = 47.86%
# Total Correct Predictions:  261 / 537
# Accuracy for the current Epoch 17 = 48.60%
# Total Correct Predictions:  262 / 537
# Accuracy for the current Epoch 18 = 48.79%
# Total Correct Predictions:  268 / 537
# Accuracy for the current Epoch 19 = 49.91%
# Total Correct Predictions:  267 / 537
# Accuracy for the current Epoch 20 = 49.72%
# Total Correct Predictions:  273 / 537
# Accuracy for the current Epoch 21 = 50.84%
# Total Correct Predictions:  272 / 537
# Accuracy for the current Epoch 22 = 50.65%
# Total Correct Predictions:  274 / 537
# Accuracy for the current Epoch 23 = 51.02%
# Total Correct Predictions:  275 / 537
# Accuracy for the current Epoch 24 = 51.21%
# Total Correct Predictions:  276 / 537
# Accuracy for the current Epoch 25 = 51.40%
# Total Correct Predictions:  280 / 537
# Accuracy for the current Epoch 26 = 52.14%
# Total Correct Predictions:  280 / 537
# Accuracy for the current Epoch 27 = 52.14%
# Total Correct Predictions:  282 / 537
# Accuracy for the current Epoch 28 = 52.51%
# Total Correct Predictions:  283 / 537
# Accuracy for the current Epoch 29 = 52.70%
# Total Correct Predictions:  284 / 537
# Accuracy for the current Epoch 30 = 52.89%
# Total Correct Predictions:  283 / 537
# Accuracy for the current Epoch 31 = 52.70%
# Total Correct Predictions:  284 / 537
# Accuracy for the current Epoch 32 = 52.89%
# Total Correct Predictions:  284 / 537
# Accuracy for the current Epoch 33 = 52.89%
# Total Correct Predictions:  282 / 537
# Accuracy for the current Epoch 34 = 52.51%
# Total Correct Predictions:  282 / 537
# Accuracy for the current Epoch 35 = 52.51%
# Total Correct Predictions:  283 / 537
# Accuracy for the current Epoch 36 = 52.70%
# Total Correct Predictions:  283 / 537
# Accuracy for the current Epoch 37 = 52.70%
# Total Correct Predictions:  285 / 537
# Accuracy for the current Epoch 38 = 53.07%
# Total Correct Predictions:  286 / 537
# Accuracy for the current Epoch 39 = 53.26%
# Total Correct Predictions:  287 / 537
# Accuracy for the current Epoch 40 = 53.45%
# Total Correct Predictions:  287 / 537
# Accuracy for the current Epoch 41 = 53.45%
# Total Correct Predictions:  289 / 537
# Accuracy for the current Epoch 42 = 53.82%
# Total Correct Predictions:  287 / 537
# Accuracy for the current Epoch 43 = 53.45%
# Total Correct Predictions:  290 / 537
# Accuracy for the current Epoch 44 = 54.00%
# Total Correct Predictions:  291 / 537
# Accuracy for the current Epoch 45 = 54.19%
# Total Correct Predictions:  293 / 537
# Accuracy for the current Epoch 46 = 54.56%
# Total Correct Predictions:  290 / 537
# Accuracy for the current Epoch 47 = 54.00%
# Total Correct Predictions:  293 / 537
# Accuracy for the current Epoch 48 = 54.56%
# Total Correct Predictions:  291 / 537
# Accuracy for the current Epoch 49 = 54.19%
# Total Correct Predictions:  291 / 537
# Accuracy for the current Epoch 50 = 54.19%
# Total Correct Predictions:  292 / 537
# Accuracy for the current Epoch 51 = 54.38%
# Total Correct Predictions:  293 / 537
# Accuracy for the current Epoch 52 = 54.56%
# Total Correct Predictions:  295 / 537
# Accuracy for the current Epoch 53 = 54.93%
# Total Correct Predictions:  295 / 537
# Accuracy for the current Epoch 54 = 54.93%
# Total Correct Predictions:  295 / 537
# Accuracy for the current Epoch 55 = 54.93%
# Total Correct Predictions:  299 / 537
# Accuracy for the current Epoch 56 = 55.68%
# Total Correct Predictions:  300 / 537
# Accuracy for the current Epoch 57 = 55.87%
# Total Correct Predictions:  299 / 537
# Accuracy for the current Epoch 58 = 55.68%
# Total Correct Predictions:  301 / 537
# Accuracy for the current Epoch 59 = 56.05%
# Total Correct Predictions:  301 / 537
# Accuracy for the current Epoch 60 = 56.05%
# Total Correct Predictions:  301 / 537
# Accuracy for the current Epoch 61 = 56.05%
# Total Correct Predictions:  303 / 537
# Accuracy for the current Epoch 62 = 56.42%
# Total Correct Predictions:  304 / 537
# Accuracy for the current Epoch 63 = 56.61%
# Total Correct Predictions:  305 / 537
# Accuracy for the current Epoch 64 = 56.80%
# Total Correct Predictions:  306 / 537
# Accuracy for the current Epoch 65 = 56.98%
# Total Correct Predictions:  308 / 537
# Accuracy for the current Epoch 66 = 57.36%
# Total Correct Predictions:  310 / 537
# Accuracy for the current Epoch 67 = 57.73%
# Total Correct Predictions:  311 / 537
# Accuracy for the current Epoch 68 = 57.91%
# Total Correct Predictions:  311 / 537
# Accuracy for the current Epoch 69 = 57.91%
# Total Correct Predictions:  310 / 537
# Accuracy for the current Epoch 70 = 57.73%
# Total Correct Predictions:  315 / 537
# Accuracy for the current Epoch 71 = 58.66%
# Total Correct Predictions:  316 / 537
# Accuracy for the current Epoch 72 = 58.85%
# Total Correct Predictions:  315 / 537
# Accuracy for the current Epoch 73 = 58.66%
# Total Correct Predictions:  315 / 537
# Accuracy for the current Epoch 74 = 58.66%
# Total Correct Predictions:  316 / 537
# Accuracy for the current Epoch 75 = 58.85%
# Total Correct Predictions:  316 / 537
# Accuracy for the current Epoch 76 = 58.85%
# Total Correct Predictions:  316 / 537
# Accuracy for the current Epoch 77 = 58.85%
# Total Correct Predictions:  318 / 537
# Accuracy for the current Epoch 78 = 59.22%
# Total Correct Predictions:  319 / 537
# Accuracy for the current Epoch 79 = 59.40%
# Total Correct Predictions:  319 / 537
# Accuracy for the current Epoch 80 = 59.40%
# Total Correct Predictions:  319 / 537
# Accuracy for the current Epoch 81 = 59.40%
# Total Correct Predictions:  321 / 537
# Accuracy for the current Epoch 82 = 59.78%
# Total Correct Predictions:  322 / 537
# Accuracy for the current Epoch 83 = 59.96%
# Total Correct Predictions:  323 / 537
# Accuracy for the current Epoch 84 = 60.15%
# Total Correct Predictions:  326 / 537
# Accuracy for the current Epoch 85 = 60.71%
# Total Correct Predictions:  328 / 537
# Accuracy for the current Epoch 86 = 61.08%
# Total Correct Predictions:  328 / 537
# Accuracy for the current Epoch 87 = 61.08%
# Total Correct Predictions:  328 / 537
# Accuracy for the current Epoch 88 = 61.08%
# Total Correct Predictions:  329 / 537
# Accuracy for the current Epoch 89 = 61.27%
# Total Correct Predictions:  331 / 537
# Accuracy for the current Epoch 90 = 61.64%
# Total Correct Predictions:  332 / 537
# Accuracy for the current Epoch 91 = 61.82%
# Total Correct Predictions:  333 / 537
# Accuracy for the current Epoch 92 = 62.01%
# Total Correct Predictions:  334 / 537
# Accuracy for the current Epoch 93 = 62.20%
# Total Correct Predictions:  334 / 537
# Accuracy for the current Epoch 94 = 62.20%
# Total Correct Predictions:  334 / 537
# Accuracy for the current Epoch 95 = 62.20%
# Total Correct Predictions:  334 / 537
# Accuracy for the current Epoch 96 = 62.20%
# Total Correct Predictions:  335 / 537
# Accuracy for the current Epoch 97 = 62.38%
# Total Correct Predictions:  335 / 537
# Accuracy for the current Epoch 98 = 62.38%
# Total Correct Predictions:  335 / 537
# Accuracy for the current Epoch 99 = 62.38%
# ************************************************** Training Complete **************************************************
# time taken:  0.36672496795654297
# Final LOG cost after training: 0.67
# Final HINGE loss after training : 0.75
# Final accuracy after training for 100 epochs = 62.38%
# Prediction: 1
# ['hyperparameters.joblib']
